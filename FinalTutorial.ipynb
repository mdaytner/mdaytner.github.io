# %% [markdown]
# <h1 text-align="center">Is Investing in the S&P500 a Clear Cut Path to Retirement?</h1>

# %%
# import sys

# try:
#     !{sys.executable} -m pip install lxml
# except Exception as e:
#     print(e)
#     print(e.__doc__)
    
import lxml
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

site = requests.get("https://www.macrotrends.net/2324/sp-500-historical-chart-data")
soup = BeautifulSoup(site.text, 'html.parser')
soup.prettify()
table = soup.find("table")
soup_string = str(table)

df = pd.read_html(soup_string)
df = df[0] # read_html resturns a list of DataFrames, pull the first DataFrame out
df
# Out:
# ...
#    S&P 500 Index - Historical Annual Data                                 \
#                                      Year AverageClosing Price Year Open
# 0                                    2021              3957.06   3700.65
# 1                                    2020              3217.86   3257.85
# 2                                    2019              2913.36   2510.03
# 3                                    2018              2746.21   2695.81
# 4                                    2017              2449.08   2257.83
# ..                                    ...                  ...       ...
# 89                                   1932                 6.92      7.82
# 90                                   1931                13.66     15.85
# 91                                   1930                21.00     21.18
# 92                                   1929                26.19     24.81
# 93                                   1928                19.94     17.76
#
#
# ...
